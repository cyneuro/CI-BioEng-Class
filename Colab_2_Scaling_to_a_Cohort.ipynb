# %% [markdown]
# # 🧭 Colab 2: Processing Multi-Subject Datasets with High-Performance Computing## Training a Neural Network on FABRIC Across All 28 Subjects### Scientific Workflows for Brain and Behavioral Research### National Science Foundation Supported Learning Initiative (Award No. OAC-2417875)#### Semester Course — Colab 2 of 5 (Weeks 3–4)---## OverviewYou extend Colab 1's single-subject workflow to the full 28-subject EEG emotion-recognition dataset — and since a dataset and model of this size are impractical on a laptop, you do the work on **FABRIC**, the national research testbed. Rather than per-electrode statistics, this Colab trains a convolutional neural network (CNN) that learns to predict which game a participant was playing directly from their EEG recording.This is also where "vibe coding" — this Colab's Primer topic — does real work for you: you'll use it to set up your FABRIC environment, and separately to teach yourself a second CI platform (CloudLab or NSG) with no prompt provided at all.Split into two submissions:- **Colab 2-1** (end of Week 3): environment setup and full-cohort data acquisition (including a real messy-data debugging exercise).- **Colab 2-2** (end of Week 4, combined): training the CNN, visualizing results, and documenting the run.---## 📋 Set Up Your Profile

# %%
# PROFILE SETUPstudent_name = "Your Name"institution = "Your University/Organization"team_name = "Your Team Name"print(f"✅ Notebook initialized for {student_name} ({institution}) — Team {team_name}")

# %% [markdown]
# ---## 🤖 Part A (Primer): Agentic AI / Vibe Coding for Neuro-Workflows### 🧭 Activity A.1 — Setting Up an Environment on FABRICYou provisioned FABRIC access back in Colab 1's Primer conceptually — now you'll actually use a session. Copy this prompt into your AI tool:> "Give me commands I can use in the ubuntu terminal to (1) install anaconda, (2) create a conda environment, (3) activate that environment, (4) install numpy, pandas, matplotlib, pytorch (GPU-compatible)."

# %%
# 💻 Activity A.1 — Paste your AI-generated FABRIC environment-setup commands here:

# %% [markdown]
# ### 🧭 Activity A.2 — Vibe-Coding HW: Exploring a New CI Platform on Your OwnEvery activity so far has given you a starting prompt to copy and refine. This one doesn't — it's the real test of vibe coding as a self-learning tool.FABRIC isn't the only national research computing platform researchers use. Two others come up often in neuroscience and CI work:* **CloudLab** — a testbed for experimenting with cloud computing infrastructure itself (networking, storage, virtualization), often used when a project needs more control over the underlying hardware/network setup than FABRIC provides.* **Neuroscience Gateway (NSG)** — a science gateway built specifically for neuroscience researchers, giving access to high-performance computing for large-scale brain modeling and data analysis without needing to manage the underlying infrastructure directly.*(Globus is a third tool worth knowing, though it does a different job: it's used for moving large research datasets reliably between institutions and computing resources, rather than for requesting compute time itself. Colab 3 has its own self-directed exploration activity for Globus.)***Task:** Your team, choose **one** of CloudLab or NSG (your instructor may assign one instead). Without a starting prompt from this notebook, use an AI tool to teach yourself:1. What the platform is for, and how it's different from FABRIC.2. How a researcher actually requests and accesses computing resources on it.3. Write (and run, if you have access; otherwise write as clearly-commented pseudocode) a short script that would request a basic compute session on your chosen platform.Since there's no prompt to copy this time, **keep a short log of your own prompt iterations**: what you asked first, what came back wrong or incomplete, and how you refined the question.

# %%
# 💻 Activity A.2 — Paste your AI-generated CloudLab/NSG exploration code here, and your prompt-iteration log:

# %% [markdown]
# ### ✍️ Part A Reflection*Double-click this cell to write your response.** **What I observed:** How did the FABRIC environment-setup process (Activity A.1, prompt given) compare to the CloudLab/NSG exploration (Activity A.2, no prompt given)?* **Connecting to key concepts:** Connects to **Certification Concepts 6 and 7** (dedicated software environments; sharing your setup via an environment file) and the new AI/Agentic track's **Vibe Coding / AI-Assisted Coding** concept.---## 💻 Part B (Build 1 of 2): Full-Cohort Data Acquisition### Topic: Scaling to 28 Subjects, and a Real Debugging ExerciseWe continue with the same EEG Emotion Recognition dataset, now acquiring data from all 28 subjects.

# %%
import kagglehubimport os# Download from kagglepath = kagglehub.dataset_download("wajahat1064/emotion-recognition-using-eeg-and-computer-games")print("Dataset downloaded to:", path)path = os.path.join(path,                     "Dataset - Emotion Recognition data Based on EEG Signals and Computer Games",                     "Database for Emotion Recognition System Based on EEG Signals and Various Computer Games - GAMEEMO",                     "GAMEEMO"                    )

# %% [markdown]
# ### 🧭 Module 1 — Building the Subject ListThe `subjects` variable should hold subject identifiers from the dataset (S01–S28). Design your own prompt with the AI to define this variable — there's no starting prompt here, since this one's a simple enough ask to write yourself.

# %%
# 💻 Module 1 — Paste your AI-generated subjects list code here:

# %%
print(len(subjects))

# %% [markdown]
# The functions below read data from a single subject and combine the resulting dataset into an array of size (subjects × game_types × channels × time). These are provided for you — no AI prompt needed.

# %%
import numpy as npimport pandas as pddef read_subject(subject, path):    assert len(os.listdir(path)) == 4    subject_recordings = []    for game_idx in range(4):        # Read channel x time data        csv_filename = f'{subject}G{game_idx + 1}AllChannels.csv'        df = pd.read_csv(os.path.join(path, csv_filename))        df.drop("Unnamed: 14", axis = 1, inplace = True)        # Shape into a channels x time array        subject_recordings.append(df.to_numpy().T)    # Shape into game_types x channels x time    subject_recordings = np.stack(subject_recordings)    return subject_recordingsdef read_subjects(subjects, path):    all_recordings = []    for subject in subjects:        subject_path = os.path.join(path, f"({subject})", "Preprocessed EEG Data", ".csv format")        data = read_subject(subject, subject_path)        all_recordings.append(data)    # Subjects x game_types x channels x time    all_recordings = np.stack(all_recordings)    return all_recordings

# %%
data = read_subjects(subjects, path)

# %% [markdown]
# ### 🧭 Module 1b — A Real Messy-Data Debugging ExerciseAs you just saw, there's an error when reading data for one of the subjects. This is a genuine data-quality issue, not a planted bug for teaching purposes — real datasets from 28 different recording sessions are rarely perfectly uniform.Design a prompt to list the contents of the problem subject's directory and compare the contents with another subject's (e.g., S01). What's the problem?

# %%
# 💻 Module 1b — Paste your AI-generated directory-comparison code here (compare the problem subject to S01):

# %% [markdown]
# Once you've diagnosed the issue, prompt AI to modify the list of subjects to exclude the problem subject (but still include the other 27).

# %%
# 💻 Module 1b — Paste your AI-generated updated subjects list here:

# %%
data = read_subjects(subjects, path)# Subjects x game_types x channels x timeprint(data.shape)

# %% [markdown]
# ### ✍️ Part B Reflection*Double-click this cell to write your response.** **What I observed:** What exactly was different about the problem subject's directory? Was this the kind of issue you could have caught by reading error messages alone, or did you need to actually compare directory contents?* **Connecting to key concepts:** Connects to **Certification Concept 39** (error-handling safeguards). At single-subject scale (Colab 1) this kind of issue wouldn't have surfaced at all — explain why cohort scale makes messy data close to inevitable.---> ## ✅ Colab 2-1 Submission Checkpoint (due end of Week 3)> Submit through the Part B reflection — the vibe-coding Primer (FABRIC setup + CloudLab/NSG exploration) and full-cohort data acquisition, including the debugging exercise.---## 🧠 Part C (Build 2 of 2): Training, Visualizing, and Documenting### Topic: A Real CNN on Real Multi-Subject Data### 🧭 Module 2 — Training an ML ModelWe'll train a convolutional neural network (CNN) to predict the game type from the temporal data across channels, for all available subjects.> "I am working with a dataset of size subjects x conditions x channels x time, my actual shape is (27, 4, 14, 38252). The data are currently stored as a numpy array. Write pytorch code that trains a simple CNN on that data to predict the condition (i.e., multiclass classification over 4 classes). Treat each subject x condition as a separate sample and make the CNN layers 1d (i.e., we convolve across time). The first layer should take 14 channels as evident from my data shape. Also leave 3 subjects out for validation (i.e., train only on 24 subjects) and add some one-time testing step (compute accuracy across the 3 subjects). Track loss and training accuracy so that I can plot them / save them later."

# %%
# 💻 Module 2 — Paste your AI-generated CNN training code here:

# %% [markdown]
# ### 🧭 Module 3 — Visualizing ResultsDesign a prompt to plot the saved train and validation losses and accuracies.

# %%
# 💻 Module 3 — Paste your AI-generated visualization code here:

# %% [markdown]
# ### 🧭 Module 4 — Documenting ResearchDesign a prompt to save the resulting train and validation losses and accuracies in a `.csv` file.

# %%
# 💻 Module 4 — Paste your AI-generated documentation code here:

# %% [markdown]
# ### 🧭 Module 5 — Additional Prompt Challenges (If Time Allows)1. **Beat the Baseline:** Use AI to modify the CNN architecture (layers, kernel sizes, channels, pooling) and improve validation accuracy.2. **Try Different Optimizers:** Replace Adam with SGD, RMSprop, or AdamW. Compare convergence speed and final accuracy.3. **Learning Rate Tuning:** Implement a learning rate scheduler (StepLR, CosineAnnealingLR, ReduceLROnPlateau) and see whether it helps.4. **Normalization Challenge:** Z-score normalize the EEG channels using only the training subjects and compare results.5. **Confusion Matrix:** Compute and visualize a confusion matrix for the held-out subjects — which conditions are most frequently confused?

# %%
# 💻 Module 5 (optional) — Paste any additional prompt-challenge code here:

# %% [markdown]
# ### ✍️ Part C Reflection*Double-click this cell to write your response.** **What I observed:** How did your model's validation accuracy compare to random chance (25%, given 4 classes)? If you attempted any Module 5 challenges, what changed?* **Connecting to key concepts:** Connects to **Certification Concepts 26, 27, and 28** (speedup factor, parallel bottleneck, CPU vs. GPU). Why does training a CNN on 27 subjects' worth of EEG data specifically benefit from FABRIC rather than a laptop?---> ## ✅ Colab 2-2 Submission Checkpoint (due end of Week 4, combined)> Submit the complete notebook (Parts A, B, and C, all reflections). This is the full Colab 2 deliverable and earns the agentic AI/vibe-coding microcredential.---## 📑 What Comes NextColab 3 goes deeper into FABRIC's resource-management side: Slurm-style job scheduling and running a brain-circuit model across multiple distributed nodes at once.

# %% [markdown]
# ---## 📖 Reference Guide: Concepts Used in Colab 2**From the master 50:** Concept 6 (dedicated software environments), Concept 7 (sharing your setup via an environment file), Concept 26 (speedup factor), Concept 27 (parallel bottleneck), Concept 28 (CPU vs. GPU), Concept 39 (error-handling safeguards).**From the new AI/Agentic/Physical AI track:** Vibe Coding / AI-Assisted Coding.**New platform explored via self-directed vibe coding:** CloudLab and Neuroscience Gateway (NSG). *(Globus gets its own self-directed exploration activity in Colab 3.)*---## ✅ Self-Check: What Did You Learn?| Concept Area | Concept | Where You Demonstrated It ||---|---|---|| Computing | Concept 6 — Dedicated software environments | [ Enter Module ID ] || Computing | Concept 26 — Speedup factor | [ Enter Module ID ] || Computing | Concept 28 — CPU vs. GPU | [ Enter Module ID ] || Computing | Concept 39 — Error-handling / messy-data debugging | [ Enter Module ID ] || AI/Vibe Coding | FABRIC environment setup via vibe coding | [ Enter Activity ID ] || AI/Vibe Coding | Self-directed platform exploration (CloudLab/NSG) | [ Enter Activity ID ] |
