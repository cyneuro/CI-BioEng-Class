# %% [markdown]
# # 🧭 Colab 4: Basics of AI, Agentic AI, and Physical AI## Scientific Workflows for Brain and Behavioral Research### National Science Foundation Supported Learning Initiative (Award No. OAC-2417875)#### Semester Course — Colab 4 of 5 (Weeks 7–8)---## OverviewThis Colab has no direct pre-workshop or onsite-lab ancestor — it's new material, folding in Notebook 05's machine-learning concepts as supporting content. It's also where a genuine physical robot (the Cutebot) enters the semester.You'll build a semi-realistic brain network for movement: a **control** component (deciding to move — reusing Colab 3's multi-node circuit model) and an **execution** component (actually moving — via the Cutebot).Split into two submissions:- **Colab 4-1** (end of Week 7): the control-network component, plus a first AI Concept Map.- **Colab 4-2** (end of Week 8, combined): the execution component integrated in, and the completed AI Concept Map.---## 📋 Set Up Your Profile

# %%
# PROFILE SETUPstudent_name = "Your Name"institution = "Your University/Organization"team_name = "Your Team Name"print(f"✅ Notebook initialized for {student_name} ({institution}) — Team {team_name}")

# %% [markdown]
# ---## 🧠🤖 Part A (Primer): AI, Agentic AI, and Physical AI### Topic: What Makes a System "Agentic," and What Makes It "Physical"### 🧭 Activity A.1 — A Small Trained Classifier, vs. a Rule> "Act as an AI/ML instructor. Write Python code that builds a very small trained classifier (any simple model — logistic regression is fine) on a toy neuro dataset (e.g., classifying two simulated movement types from simulated sensor features), and *separately* write a hand-coded rule that attempts the same classification without training. Compare their accuracy and explain in comments what 'learned from data' means in contrast to 'rule-based'."

# %%
# 💻 Activity A.1 — Paste your AI-generated trained-vs-rule-based comparison code here:

# %% [markdown]
# ### 🧭 Activity A.2 — The Perception–Decision–Action Loop> "Write a small simulated 'agent' in Python that repeatedly: (1) senses a simple environment value, (2) decides on an action based on that value, (3) acts by changing the environment, and (4) senses the result — looping several times. Add comments labeling each part of the loop, and note where a human could optionally review the decision before it's carried out (human-in-the-loop)."

# %%
# 💻 Activity A.2 — Paste your AI-generated perception-decision-action loop code here:

# %% [markdown]
# ### ✍️ Part A Reflection*Double-click this cell to write your response.** **What I observed:** Where did the trained classifier outperform the hand-coded rule, and where might the rule actually be safer or more predictable?* **Connecting to key concepts:** Connects to the new **AI/Agentic/Physical AI track**: Machine Learning, Rule-Based vs. Learned Control, Perception–Decision–Action Loop, Human-in-the-Loop.---## 🧠 Part B (Build 1 of 2): The Control Network### Topic: Deciding to Move### 🧭 Activity B.1 — From Raw Circuit Output to a Movement Decision> "Take the multi-node brain-circuit model from Colab 3. Write code that turns its continuous output into a discrete movement *decision* (e.g., move-forward / turn-left / turn-right / stop) rather than a raw value — this is the 'control' half of a movement network. Add comments explaining the decision rule you used and whether it's rule-based or learned."

# %%
# 💻 Activity B.1 — Paste your AI-generated control-decision code here:

# %% [markdown]
# ### ✍️ Part B Reflection + AI Concept Map (Draft)*Double-click this cell to write your response.** **What I observed:** What information got lost (or simplified) when you converted the raw circuit output into a discrete decision?* **AI Concept Map — Draft (control component only):** List each functional block in your control pipeline so far (perception → decision) and label each as *agentic*, *physical AI*, *classical ML*, or *rule-based/hard-coded*, with brief justification. This draft gets extended once the execution component is added in Part C.---> ## ✅ Colab 4-1 Submission Checkpoint (due end of Week 7)> Submit through the Part B reflection and AI Concept Map draft — the AI/Agentic/Physical AI Primer and the control-network build.---## 🚗 Part C (Build 2 of 2): The Execution Component — Cutebot Integration### Topic: Actually Making the Movement### 🧭 Activity C.1 — Translating a Decision Into Robot Motion> "Write code that takes the movement decision from Activity B.1 (move-forward / turn-left / turn-right / stop) and translates it into wheel commands for a Cutebot-style rear-wheel-drive robot car (a simulation is fine if you don't have the physical kit yet). Add comments explaining how each decision maps to a specific pair of wheel speeds."

# %%
# 💻 Activity C.1 — Paste your AI-generated Cutebot control code here:

# %% [markdown]
# ### 🧭 Activity C.2 — Extension: An Emotion-Aware Movement NetworkYour Cutebot pipeline so far responds to one signal: the movement decision. This extension adds a second, independent signal — the same emotion-aware pattern that used to open this course back in Colab 1, before Colabs 1 and 2 were rebuilt around real datasets. It's a genuinely good pattern, so it's moved here rather than being dropped.**Step 1 — Build a simple EEG emotion classifier:**> "Act as a neuroscience-AI instructor. Write a Python script that:> 1. Generates synthetic EEG-like signals for two emotional states (e.g., 'calm' and 'alert'), each with a distinct simple pattern (e.g., different dominant frequency bands).> 2. Extracts a simple feature from each signal (e.g., band power in a chosen frequency range).> 3. Uses a basic classifier (a simple threshold rule or a small trained model — either is fine) to label the current state as 'calm' or 'alert'.> Add plain-language comments explaining what the feature represents and how the classifier makes its decision."

# %%
# 💻 Activity C.2, Step 1 — Paste your AI-generated EEG emotion-classifier code here:

# %% [markdown]
# **Step 2 — Integrate it into your Cutebot pipeline:**> "Extend my Cutebot control pipeline by adding the emotion classifier above as a second, independent input. The robot's behavior should now reflect **two** signals at once: the movement decision from the control network, and the current emotional-state label from the classifier (for example, the robot's speed changes with the classified state, while the movement decision still controls direction). Add comments explaining how the two signals combine without interfering with each other."

# %%
# 💻 Activity C.2, Step 2 — Paste your AI-generated integrated pipeline code here:

# %% [markdown]
# ### ✍️ Part C Reflection + AI Concept Map (Completed)*Double-click this cell to write your response.** **What I observed:** What would need to change to make your rule-based decision step (if it is one) into something agentic — i.e., something that could learn or adjust its own decision rule over time?* **On the emotion-aware extension (C.2):** Is your emotion classifier closer to "rule-based" or "learned" control? How does adding it change the AI Concept Map compared to the control+execution pipeline alone?* **AI Concept Map — Completed:** Extend your Part B draft to include the execution component (Cutebot) *and*, if you completed Activity C.2, the emotion classifier. Finalize the classification (agentic / physical AI / classical ML / rule-based) for every block in the full pipeline.---> ## ✅ Colab 4-2 Submission Checkpoint (due end of Week 8, combined)> Submit the complete notebook (Parts A, B, and C, all reflections, completed AI Concept Map). This is the full Colab 4 deliverable and earns the AI/Agentic/Physical AI microcredential.>> **Capstone scoping discussion this week** — start narrowing down your team's approach to its selected capstone project.---## 📑 What Comes NextColab 5 introduces the SEL/Tuckman model and brain circuits underlying team dynamics — and puts several teams' movement networks into the same shared task, requiring inter-team coordination without a single point of control.

# %% [markdown]
# ---## 📖 Reference Guide: Concepts Used in Colab 4**From the master 50:** Concept 23 (Machine Learning for Neural Decoding).**From the new AI/Agentic/Physical AI track:** Artificial Intelligence, Machine Learning, Training vs. Inference, Agent/Agentic AI, Autonomy Spectrum, Physical AI/Embodied AI, Perception–Decision–Action Loop, Rule-Based vs. Learned Control, Human-in-the-Loop, Documenting an AI Component.**Preserved from the earlier Colab 1/2 curriculum:** the emotion-aware second-signal pattern (Activity C.2), now applied to the Cutebot pipeline instead of a generic robot.---## ✅ Self-Check: What Did You Learn?| Concept Area | Concept | Where You Demonstrated It ||---|---|---|| AI Fundamentals | Machine Learning vs. rule-based control | [ Enter Activity ID ] || AI Fundamentals | Perception–Decision–Action Loop | [ Enter Activity ID ] || AI Fundamentals | Physical AI / Embodied AI | [ Enter Activity ID ] || AI Fundamentals | Human-in-the-Loop | [ Enter Activity ID ] || AI Fundamentals | Autonomy Spectrum | [ Enter Activity ID ] || AI Fundamentals | Emotion classifier as a second, independent signal | [ Enter Activity ID ] |
