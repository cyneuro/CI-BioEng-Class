# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cyneuro/CI-COURSE/blob/main/Colab_5_SEL_Tuckman_Team_Dynamics.ipynb)
#
# # 🧭 Colab 5: SEL/Tuckman Model — Brain Circuits and Team Dynamics
# ## Scientific Workflows for Brain and Behavioral Research
# ### National Science Foundation Supported Learning Initiative (Award No. OAC-2417875)
# #### Semester Course — Colab 5 of 5 (Weeks 9–11, spans Spring Break)
#
# ***
#
# ## Overview
#
# Like Colab 4, this Colab has no pre-workshop or onsite-lab ancestor. It's also the only Colab where the "build" is explicitly social as much as technical: multiple teams, each controlling one simulated brain region and its own robot, have to coordinate toward a shared goal with no single team in charge.
#
# Split into two submissions, with Spring Break in between:
# - **Colab 5-1** (end of Week 9): each team builds its own robot-control component, solo.
# - **Colab 5-2** (end of Week 11, combined, after Spring Break): teams coordinate their independently-built pieces toward a shared goal.
#
# ***
# ## 📋 Set Up Your Profile

# %%
# PROFILE SETUP
student_name = "Your Name"
institution = "Your University/Organization"
team_name = "Your Team Name"
brain_region_assigned = "e.g., Motor Cortex / Cerebellum / Basal Ganglia — your team's region"
print(f"✅ Notebook initialized for {student_name} ({institution}) — Team {team_name}")
print(f"Assigned brain region: {brain_region_assigned}")

# %% [markdown]
# ***
# ## 🧠🤝 Part A (Primer): SEL/Tuckman Model; Brain Circuits and Team Dynamics
# ### Topic: How Teams Develop, and What the Brain Has to Do With It
#
# This Primer is less about writing code and more about recognizing patterns in your own team — but we'll still use the Ask → Build → Document cycle, with the AI tool generating scenarios to analyze rather than code to run.
#
# ### 🧭 Activity A.1 — Generating a Tuckman-Stage Scenario
#
# > "Act as an organizational psychology instructor. Write a short (1-paragraph) realistic scenario for each of Tuckman's five stages (Forming, Storming, Norming, Performing, Adjourning) as they might play out in a small technical project team of undergraduates. Keep each scenario concrete and specific rather than abstract."
#
# Read the five scenarios your AI tool generates. In the cell below, note which one already feels most familiar from your own team experience so far, and why.

# %%
# 📝 Activity A.1 — Paste the AI-generated scenarios here, and your one-paragraph response:

# %% [markdown]
# ### 🧭 Activity A.2 — A Distributed-Leadership Team Charter
#
# > "Write a short team-charter template that assigns leadership by task rather than by fixed role — i.e., whoever has the most relevant skill or context for a given decision leads that decision. Include a section on psychological safety: what your team commits to so that raising a concern or admitting a mistake doesn't get punished."
#
# Fill in the generated charter template for your own team in the cell below.

# %%
# 📝 Activity A.2 — Paste your completed team charter here:

# %% [markdown]
# ### ✍️ Part A Reflection
# *Double-click this cell to write your response.*
#
# * **What I observed:** Which Tuckman stage does your team seem to be in right now, four weeks into working together (since Colab 3's capstone team selection)? What's your evidence?
# * **Connecting to key concepts:** Connects to the new **SEL/Tuckman track**: Theory of Mind, Executive Function, Psychological Safety, Distributed Leadership.
#
# ***
# ## 🤖 Part B (Build 1 of 2): Your Team's Solo Robot-Control Component
# ### Topic: Building Before Coordinating
#
# ### 🧭 Activity B.1 — One Brain Region, One Robot, No Coordination Yet
#
# > "Adapt one sub-network from your team's Colab 3/4 work to represent a single brain region (e.g., motor cortex, cerebellum, or basal ganglia — pick one). Write code that has this region's network control one robot on its own, with no communication to any other team's robot yet. Add comments explaining what task this region's output is meant to accomplish by itself."

# %%
# 💻 Activity B.1 — Paste your AI-generated solo brain-region/robot control code here:

# %% [markdown]
# ### ✍️ Part B Reflection (Team Dynamics — Sub 1)
# *Double-click this cell to write your response.*
#
# * **What I observed:** Building this piece solo (before any inter-team coordination), what roles or expectations emerged inside *your own* team — who took the lead on what, and how was that decided?
# * **This is the Forming-stage half of your Team Dynamics Reflection.** The rest gets added in Part C, after coordination begins.
#
# ***
# > ## ✅ Colab 5-1 Submission Checkpoint (due end of Week 9)
# > Submit through the Part B reflection — the SEL/Tuckman Primer and each team's solo robot-control component.
#
# ***
# ## 🕐 SPRING BREAK 🕐
#
# ***
# ## 🤝🤖 Part C (Build 2 of 2): Multi-Team, Multi-Robot Coordination
# ### Topic: No Single Point of Control
#
# ### 🧭 Activity C.1 — Coordinating Independently-Controlled Robots
#
# > "Multiple teams have each built a brain-region network controlling its own robot, independently. Write a coordination protocol (a simple shared signal, message-passing scheme, or turn-taking rule) that lets these independently-controlled robots work toward one shared goal — without any single robot or team having full control. Add comments explaining how this mirrors different brain regions coordinating to produce one coherent body movement."

# %%
# 💻 Activity C.1 — Paste your AI-generated multi-team coordination protocol code here:

# %% [markdown]
# ### 🧭 Activity C.2 — Automated Control, Without User Input
#
# > "Extend the coordination protocol from Activity C.1 so it runs autonomously once started — no person needs to intervene to keep the robots coordinating turn to turn. Note in comments any point where a human-in-the-loop check was deliberately removed, and whether you think that was the right call."

# %%
# 💻 Activity C.2 — Paste your AI-generated autonomous-coordination code here:

# %% [markdown]
# ### ✍️ Part C Reflection — Team Dynamics Reflection (Completed)
# *Double-click this cell to write your response.*
#
# Complete the full reflection, building on your Part B (Forming-stage) response:
#
# * **Tuckman-stage mapping:** For each of Forming, Storming, Norming, Performing, and Adjourning, cite one specific incident or decision your team actually experienced — during the solo build (Part B) or the coordination work (Part C).
# * **Inter-team friction or success:** Identify one moment of coordination friction or success *between* teams, and explain it using at least one brain-circuit concept from the Primer (e.g., theory of mind, executive function, reward/social-learning circuits).
# * **Leadership shift:** One paragraph — how did leadership roles shift, or fail to shift, as your team moved from solo building to inter-team coordination?
#
# ***
# > ## ✅ Colab 5-2 Submission Checkpoint (due end of Week 11, combined)
# > Submit the complete notebook (Parts A, B, and C, all reflections, completed Team Dynamics Reflection). This is the full Colab 5 deliverable and earns the SEL/Tuckman microcredential.
# >
# > **Team debrief this week** — as a class, name what just happened in Tuckman-stage terms.
#
# ***
# ## 📑 What Comes Next
#
# Weeks 12–16 are the Capstone: your team's selected faculty-sourced project, applying everything from Colabs 1–5 (the four-stage workflow, FABRIC, AI modules, and — very likely — the team dynamics you just lived through) to a real research question.

# %% [markdown]
# ***
# ## 📖 Reference Guide: Concepts Used in Colab 5
#
# **From the new SEL/Tuckman track:** [Forming](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC1), [Storming](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC2), [Norming](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC3), [Performing](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC4), [Adjourning](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC5), [Non-Linear Development](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC6), [Social-Emotional Learning (SEL)](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC7), [Theory of Mind](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC8), [Mirror Neuron System](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC9), [Executive Function](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC10), [Social Reward Circuits](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC11), [Psychological Safety](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC12), [Perspective-Taking vs. Assumption](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC13), [Distributed Leadership](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC14), [Conflict as Information](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC15).
#
# **From the AI/Agentic/Physical AI track:** [Autonomy Spectrum](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackB6), [Human-in-the-Loop](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackB13) (revisited here in a team-coordination context).
#
# ***
# ## ✅ Self-Check: What Did You Learn?
#
# | Concept Area | Concept | Where You Demonstrated It |
# |---|---|---|
# | SEL/Tuckman | [Forming](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC1) | [ Enter Activity ID ] |
# | SEL/Tuckman | [Storming](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC2) | [ Enter Activity ID ] |
# | SEL/Tuckman | [Psychological Safety](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC12) | [ Enter Activity ID ] |
# | SEL/Tuckman | [Distributed Leadership](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC14) | [ Enter Activity ID ] |
# | SEL/Tuckman | [Theory of Mind](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC8) / [Executive Function](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC10) | [ Enter Activity ID ] |
# | AI/Agentic | [Autonomy Spectrum](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackB6) (multi-robot, no user input) | [ Enter Activity ID ] |
