# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cyneuro/CI-COURSE/blob/main/Colab_5_SEL_Tuckman_Team_Dynamics.ipynb)
#
#
#
# # 🧭 Colab 5: SEL/Tuckman Model — Brain Circuits and Team Dynamics
#
# ## Scientific Workflows for Brain and Behavioral Research
#
# ### National Science Foundation Supported Learning Initiative (Award No. OAC-2417875)
#
# #### Semester Course — Colab 5 of 5 (Weeks 9–11, spans Spring Break)
#
#
#
# ***
#
#
#
# ## Overview
#
#
#
# Like Colab 4, this Colab has no pre-workshop or onsite-lab ancestor. It's also the only Colab where the "build" is explicitly social as much as technical: multiple teams, each controlling one simulated brain region and its own robot, have to coordinate toward a shared goal with no single team in charge.
#
#
#
# Split into two submissions, with Spring Break in between:
#
# - **Colab 5-1** (end of Week 9): each team builds its own robot-control component, solo.
#
# - **Colab 5-2** (end of Week 11, combined, after Spring Break): teams coordinate their independently-built pieces toward a shared goal.
#
#
#
# ***
#
# ## 📋 Set Up Your Profile

# %%
# PROFILE SETUP

student_name = "Your Name"

institution = "Your University/Organization"

team_name = "Your Team Name"

brain_region_assigned = "e.g., Motor Cortex / Cerebellum / Basal Ganglia — your team's region"

print(f"✅ Notebook initialized for {student_name} ({institution}) — Team {team_name}")

print(f"Assigned brain region: {brain_region_assigned}")

# %% [markdown]
# ***
#
# ## 🧠🤝 Part A (Primer): SEL/Tuckman Model; Brain Circuits and Team Dynamics
#
# ### Topic: How Teams Develop, and What the Brain Has to Do With It
#
#
#
# This Primer is less about writing code and more about recognizing patterns in your own team — but we'll still use the Ask → Build → Document cycle, with the AI tool generating scenarios to analyze rather than code to run.
#
#
#
# ### 🧭 Activity A.1 — Generating a Tuckman-Stage Scenario
#
#
#
# > "Act as an organizational psychology instructor. Write a short (1-paragraph) realistic scenario for each of Tuckman's five stages (Forming, Storming, Norming, Performing, Adjourning) as they might play out in a small technical project team of undergraduates. Keep each scenario concrete and specific rather than abstract."
#
#
#
# Read the five scenarios your AI tool generates. In the cell below, note which one already feels most familiar from your own team experience so far, and why.

# %%
# 📝 Activity A.1 — Paste the AI-generated scenarios here, and your one-paragraph response:

# %% [markdown]
# ### 🧭 Activity A.2 — A Distributed-Leadership Team Charter
#
#
#
# > "Write a short team-charter template that assigns leadership by task rather than by fixed role — i.e., whoever has the most relevant skill or context for a given decision leads that decision. Include a section on psychological safety: what your team commits to so that raising a concern or admitting a mistake doesn't get punished."
#
#
#
# Fill in the generated charter template for your own team in the cell below.

# %%
# 📝 Activity A.2 — Paste your completed team charter here:

# %% [markdown]
# ### ✍️ Part A Reflection
#
# *Double-click this cell to write your response.*
#
#
#
# * **What I observed:** Which Tuckman stage does your team seem to be in right now, four weeks into working together (since Colab 3's capstone team selection)? What's your evidence?
#
# * **Connecting to key concepts:** Connects to the new **SEL/Tuckman track**: Theory of Mind, Executive Function, Psychological Safety, Distributed Leadership.
#
#
#
# ***
#
# ## 🤖 Part B (Build 1 of 2): Your Team's Solo Robot-Control Component
#
# ### Topic: Building Before Coordinating
#
#
#
# ### 🧭 Activity B.1 — One Brain Region, One Robot, No Coordination Yet
#
#
#
# > "Adapt one sub-network from your team's Colab 3/4 work to represent a single brain region (e.g., motor cortex, cerebellum, or basal ganglia — pick one). Write code that has this region's network control one robot on its own, with no communication to any other team's robot yet. Add comments explaining what task this region's output is meant to accomplish by itself."

# %%
# 💻 Activity B.1 — Paste your AI-generated solo brain-region/robot control code here:

# %% [markdown]
# ### ✍️ Part B Reflection (Team Dynamics — Sub 1)
#
# *Double-click this cell to write your response.*
#
#
#
# * **What I observed:** Building this piece solo (before any inter-team coordination), what roles or expectations emerged inside *your own* team — who took the lead on what, and how was that decided?
#
# * **This is the Forming-stage half of your Team Dynamics Reflection.** The rest gets added in Part C, after coordination begins.
#
#
#
# ***
#
# > ## ✅ Colab 5-1 Submission Checkpoint (due end of Week 9)
#
# > Submit through the Part B reflection — the SEL/Tuckman Primer and each team's solo robot-control component.
#
#
#
# ***
#
# ## 🕐 SPRING BREAK 🕐
#
#
#
# ***
#
# ## 🤝🤖 Part C (Build 2 of 2): Multi-Team, Multi-Robot Coordination
#
# ### Topic: No Single Point of Control
#
#
#
# ### 🧭 Activity C.1 — Coordinating Independently-Controlled Robots
#
#
#
# > "Multiple teams have each built a brain-region network controlling its own robot, independently. Write a coordination protocol (a simple shared signal, message-passing scheme, or turn-taking rule) that lets these independently-controlled robots work toward one shared goal — without any single robot or team having full control. Add comments explaining how this mirrors different brain regions coordinating to produce one coherent body movement."

# %%
# 💻 Activity C.1 — Paste your AI-generated multi-team coordination protocol code here:

# %% [markdown]
# ### 🧭 Activity C.2 — Automated Control, Without User Input
#
#
#
# > "Extend the coordination protocol from Activity C.1 so it runs autonomously once started — no person needs to intervene to keep the robots coordinating turn to turn. Note in comments any point where a human-in-the-loop check was deliberately removed, and whether you think that was the right call."

# %%
# 💻 Activity C.2 — Paste your AI-generated autonomous-coordination code here:

# %% [markdown]
# ### ✍️ Part C Reflection — Team Dynamics Reflection (Completed)
#
# *Double-click this cell to write your response.*
#
#
#
# Complete the full reflection, building on your Part B (Forming-stage) response:
#
#
#
# * **Tuckman-stage mapping:** For each of Forming, Storming, Norming, Performing, and Adjourning, cite one specific incident or decision your team actually experienced — during the solo build (Part B) or the coordination work (Part C).
#
# * **Inter-team friction or success:** Identify one moment of coordination friction or success *between* teams, and explain it using at least one brain-circuit concept from the Primer (e.g., theory of mind, executive function, reward/social-learning circuits).
#
# * **Leadership shift:** One paragraph — how did leadership roles shift, or fail to shift, as your team moved from solo building to inter-team coordination?
#
#
#
# ***
#
# > ## ✅ Colab 5-2 Submission Checkpoint (due end of Week 11, combined)
#
# > Submit the complete notebook (Parts A, B, and C, all reflections, completed Team Dynamics Reflection). This is the full Colab 5 deliverable and earns the SEL/Tuckman microcredential.
#
# >
#
# > **Team debrief this week** — as a class, name what just happened in Tuckman-stage terms.
#
#
#
# ***
#
# ## 📑 What Comes Next
#
#
#
# Weeks 12–16 are the Capstone: your team's selected faculty-sourced project, applying everything from Colabs 1–5 (the four-stage workflow, FABRIC, AI modules, and — very likely — the team dynamics you just lived through) to a real research question.

# %% [markdown]
# ***
# ## 🎯 Foundational Concepts: This Colab's Microcredential Targets
#
# This section is the actual outcome of Colab 5's microcredential — not an afterthought at the end. Below are the 10 core concepts this Colab is built to teach: Forming, Storming, Norming, Performing, Theory of Mind, Executive Function, Psychological Safety, Distributed Leadership, Conflict as Information, Giving/Receiving Feedback.
#
# For each one: read the short resource, run the code if there is any, then **go find and answer a real practice question about it from somewhere other than this course** — a textbook companion site, a university's open courseware quiz, a MOOC's practice set, anywhere. These 10 concepts are exactly what the Target Questions at the end of this Colab — and later, the quizzes and Final — will test.

# %% [markdown]
# ### Concept 1 — Forming
#
# **Resource:** Tuckman's first team stage: members are polite, cautious, and unsure of roles or goals. Most teams are here in their first meeting or two — before anyone's actually been tested by real disagreement.

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *Tuckman's stages of team development, Forming stage* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 2 — Storming
#
# **Resource:** Conflict emerges as differing opinions and working styles surface — often the most uncomfortable of Tuckman's stages, but not a sign the team is failing; it's usually a sign the team is actually starting to engage honestly.

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *Tuckman's Storming stage or team conflict* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 3 — Norming
#
# **Resource:** The team develops shared expectations, roles settle, and cooperation improves — conflicts that used to escalate now get raised as questions instead of arguments.

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *Tuckman's Norming stage* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 4 — Performing
#
# **Resource:** The team operates efficiently with minimal supervision, focused on the shared task — the stage every team wants to reach, though teams can slip backward from here if membership or stakes change.

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *Tuckman's Performing stage* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 5 — Theory of Mind
#
# **Resource:** The brain's capacity to represent that another person has their own beliefs and intentions, different from your own — foundational to teamwork, since assuming everyone thinks like you do is a fast way to misread a teammate's silence or hesitation.

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *theory of mind in social cognition* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 6 — Executive Function
#
# **Resource:** Prefrontal-cortex-supported abilities — inhibition, working memory, flexible switching — that let a person regulate their own behavior during team conflict, like holding back a frustrated reaction when a decision doesn't go your way.

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *executive function and self-regulation* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 7 — Psychological Safety
#
# **Resource:** A shared team belief that it's safe to take interpersonal risks — asking questions, admitting mistakes — without being punished or embarrassed. Teams with high psychological safety catch errors earlier, because people actually speak up.

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *psychological safety in teams (Amy Edmondson's research)* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 8 — Distributed Leadership
#
# **Resource:** Leadership that shifts to whoever has the most relevant skill or context at a given moment, rather than residing permanently in one fixed role — the person who set up the FABRIC environment leads that decision; the person who wrote the analysis leads that one.

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *distributed or shared leadership models* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 9 — Conflict as Information
#
# **Resource:** Reframing team friction as a signal about unmet needs or unclear expectations, rather than purely a problem to suppress — the disagreement itself is data about something that needs to be resolved, not just noise.

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *productive conflict in teams* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 10 — Giving/Receiving Feedback
#
# **Resource:** A trainable skill distinct from psychological safety itself: framing feedback around specific behavior rather than character ("the results weren't logged" vs. "you're careless"), and receiving feedback without immediately defending — both take practice, not just good intentions.

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *giving and receiving feedback in team settings* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ***
# ## 🎯 Target Questions
#
# These are the questions the 10 concepts above prepare you for. They're the same concepts — and often close to the same format — as what appears on the quizzes and Final. **Each question has exactly TWO correct answers**, matching the actual quiz format.
#
# **1.** Which TWO correctly describe Tuckman's Forming stage?
# A) Members are polite and cautious.
# B) Roles and goals are not yet settled.
# C) Conflict is at its peak.
# D) The team operates with minimal supervision.
# E) Cooperation has already fully stabilized.
#
# **2.** Which TWO correctly describe Tuckman's Storming stage?
# A) Conflict emerges as differing opinions and working styles surface.
# B) It's often the most uncomfortable of Tuckman's stages.
# C) It's a sign the team is permanently failing.
# D) Members are still polite and cautious, unsure of roles.
# E) The team already operates efficiently with minimal oversight.
#
# **3.** Which TWO correctly describe Tuckman's Norming stage?
# A) Shared expectations develop among team members.
# B) Roles settle and cooperation improves.
# C) Conflict is at its most intense here.
# D) The team's work has already concluded.
# E) Members are meeting each other for the first time.
#
# **4.** Which TWO correctly describe Tuckman's Performing stage?
# A) The team operates efficiently with minimal supervision.
# B) Teams can slip backward from here if membership or stakes change.
# C) It always comes before Storming.
# D) It is identical to the Forming stage.
# E) It means the team's work is now permanently finished.
#
# **5.** Which TWO correctly describe theory of mind?
# A) The brain's capacity to represent that another person has beliefs different from one's own.
# B) It underlies understanding a teammate's perspective in disagreement.
# C) It refers to a team's written project plan.
# D) It is a scheduling technique for meetings.
# E) It refers to a brain region responsible only for motor control.
#
# **6.** Which TWO correctly describe executive function?
# A) Prefrontal-cortex-supported abilities like inhibition and working memory.
# B) It lets a person regulate their own behavior during team conflict.
# C) It refers only to empathy and imitation of others' actions.
# D) It has nothing to do with self-regulation.
# E) It describes a team-level property rather than an individual one.
#
# **7.** Which TWO correctly describe psychological safety?
# A) A shared team belief that it's safe to take interpersonal risks.
# B) Team members won't be punished for asking questions or admitting mistakes.
# C) A guarantee that no team member will ever disagree.
# D) A rule requiring one designated leader for the whole project.
# E) A method for physically protecting lab equipment.
#
# **8.** Which TWO correctly describe distributed leadership?
# A) Leadership shifts to whoever has the most relevant skill or context.
# B) It is not fixed to one person for the entire project.
# C) Leadership is assigned once, at the start, and never changes.
# D) There is no leader at any point in the project.
# E) Leadership can only be held by the most senior team member.
#
# **9.** Which TWO correctly describe "conflict as information"?
# A) It reframes team friction as a signal about unmet needs or unclear expectations.
# B) It treats conflict as informative rather than purely a problem to suppress.
# C) It means teams should avoid all conflict entirely.
# D) It has nothing to do with expectations or needs.
# E) It treats conflict as a purely negative outcome with no value.
#
# **10.** Which TWO describe effective feedback practice?
# A) Framing feedback around specific behavior rather than character.
# B) Receiving feedback without immediately becoming defensive.
# C) Feedback should always focus on personality traits.
# D) Good feedback requires no practice, only good intentions.
# E) Feedback is only useful when given by a formal team leader.

# %% [markdown]
# ### Answer Key (self-check)
#
# 1. A,B  2. A,B  3. A,B  4. A,B  5. A,B  6. A,B  7. A,B  8. A,B  9. A,B  10. A,B

# %% [markdown]
# ***
# ## ✍️ Now It's Your Turn: Write 10 Target Questions of Your Own
#
# You've worked through 10 concept resources, hunted down external practice questions for each, and answered the 10 official Target Questions above. Now flip the process: write **10 of your own** target-style questions covering this Colab's material.
#
# Your questions can be:
# - Harder or more specific versions of the concepts above,
# - Questions about something this Colab covered that wasn't in the official 10,
# - Questions inspired by whatever you found during your Find-and-Practice research.
#
# Use the same two-answer-select format (5 options, exactly 2 correct) or a short conceptual question — whichever fits the idea better. Include the correct answer(s) and a one-sentence explanation for each.
#
# **Why this matters:** writing a good test question requires understanding the material more deeply than just answering one — you have to know not just what's true, but what's *plausibly wrong* (the distractors). This is also genuinely useful beyond your own studying: your best questions may get folded into a future semester's quiz bank, the same way the Advanced Explorations Library's Field-Scan Challenge (Option E) uses student proposals to keep that material current.

# %%
# ✍️ Write your 10 original questions, answers, and explanations here:

# %% [markdown]
# ***
# ## 📖 Reference Guide: Concepts Used in Colab 5
#
# **From the new SEL/Tuckman track:** [Forming](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC1), [Storming](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC2), [Norming](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC3), [Performing](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC4), [Adjourning](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC5), [Non-Linear Development](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC6), [Social-Emotional Learning (SEL)](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC7), [Theory of Mind](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC8), [Mirror Neuron System](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC9), [Executive Function](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC10), [Social Reward Circuits](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC11), [Psychological Safety](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC12), [Perspective-Taking vs. Assumption](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC13), [Distributed Leadership](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC14), [Conflict as Information](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC15).
#
# **From the AI/Agentic/Physical AI track:** [Autonomy Spectrum](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackB6), [Human-in-the-Loop](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackB13) (revisited here in a team-coordination context).
#
# ***
# ## ✅ Self-Check: What Did You Learn?
#
# | Concept Area | Concept | Where You Demonstrated It |
# |---|---|---|
# | SEL/Tuckman | [Forming](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC1) | [ Enter Activity ID ] |
# | SEL/Tuckman | [Storming](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC2) | [ Enter Activity ID ] |
# | SEL/Tuckman | [Psychological Safety](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC12) | [ Enter Activity ID ] |
# | SEL/Tuckman | [Distributed Leadership](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC14) | [ Enter Activity ID ] |
# | SEL/Tuckman | [Theory of Mind](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC8) / [Executive Function](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackC10) | [ Enter Activity ID ] |
# | AI/Agentic | [Autonomy Spectrum](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackB6) (multi-robot, no user input) | [ Enter Activity ID ] |
