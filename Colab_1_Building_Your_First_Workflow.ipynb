# %% [markdown]
# # 🧭 Colab 1: Building Your First Research Workflow## Single-Subject EEG Emotion Analysis Pipeline### Scientific Workflows for Brain and Behavioral Research### National Science Foundation Supported Learning Initiative (Award No. OAC-2417875)#### Semester Course — Colab 1 of 5 (Weeks 1–2)---## OverviewThis Colab now runs on the Workshop's actual current curriculum: real EEG data recorded while a participant played four emotionally different computer games (boring, calm, horror, funny). You'll build a four-stage pipeline — data acquisition, per-electrode statistical analysis, visualization, and documentation — for a single participant (S01), acting as a **Workflow Designer** the whole way: you pass each "AI Prompt Challenge" to an AI coding assistant, evaluate what it returns, and drop it into the notebook.This Colab is split into two submissions:- **Colab 1-1** (end of Week 1): data acquisition and statistical analysis.- **Colab 1-2** (end of Week 2, combined): visualization, documentation, and the Embedded Playground tasks.---## 📋 Set Up Your Profile

# %%
# PROFILE SETUPstudent_name = "Your Name"institution = "Your University/Organization"team_name = "Your Team Name"print(f"✅ Notebook initialized for {student_name} ({institution}) — Team {team_name}")

# %% [markdown]
# ---## 🖥️ Part A (Primer): CI Hardware/Software, Including Edge Computing### Topic: The General Pattern for Accessing National Research ComputingSome research questions need more computing power than a laptop or Google Colab can provide. Getting access to that kind of power almost always follows the same general pattern, no matter which specific system you end up using: **create an account, get approved for a project, generate a security credential, and confirm you're connected.** FABRIC — a national research testbed — is this course's worked example, but the pattern transfers directly to your own institution's HPC cluster or any other system your research group uses. You'll provision and use a real FABRIC session starting in Colab 2.### 🧭 Activity A.1 — Understanding Your Compute EnvironmentsBefore requesting any real computing resources, it's worth knowing what you're actually choosing between. Three environments come up throughout this course:| Environment | What it actually is | Reaches FABRIC directly? | Best for ||---|---|---|---|| **Google Colab** | A free, hosted Jupyter notebook in your browser. Nothing to install; nothing persists on its own. | ❌ No dependable network path into a research testbed | Quick, shareable, zero-install work || **A testbed's own JupyterHub** (e.g., FABRIC's) | A multi-user Jupyter deployment the testbed itself runs, inside its own network, with its toolkit and your credentials already configured. | ✅ Yes — that's the whole point of running it there | Provisioning, running, and releasing real computing sessions || **VSCode (with Remote-SSH)** | A full code editor that can open a direct terminal/file connection to a remote machine, including a running compute node. | ✅ Yes, once you already have a running session to connect to | Serious day-to-day development once a session already exists |**Ask your AI tool:** copy the prompt below, filling in your own research area.> "I just learned about three computing environments: Google Colab (hosted, zero-install, no direct HPC access), a research testbed's own JupyterHub (pre-configured, reaches the testbed's compute directly), and VSCode with Remote-SSH (a full editor that connects to an already-running remote session). My research involves [describe your data/analysis needs]. Which of these three would I actually reach for at each stage of my work, and why?"

# %%
# 📝 Activity A.1 — Paste your AI conversation and your own short answer here:

# %% [markdown]
# ### ✍️ Part A Reflection*Double-click this cell to write your response.** **What I observed:** Which environment did your AI conversation point you toward, and did that match your own intuition beforehand?* **Connecting to key concepts:** Connects to **FABRIC Concepts 1 (Research Testbed), 8 (Project Membership), and 16–18 (Compute Environments)**. Why can't Colab reach a research testbed's compute directly, even though it can run the same Python code?---## 💻 Part B (Build 1 of 2): Data Acquisition and Statistical Analysis### Topic: A Real Single-Subject EEG DatasetYou'll work with a real dataset: EEG signals recorded from a participant (S01) playing four emotionally different computer games — boring, calm, horror, funny.### 🧭 Module 1 — Data Acquisition> Copy the code block below into your notebook, then copy this prompt into your AI tool:>> "Write a function `get_data(data_config)` that takes the `DATA_CONFIG` below, reads each file with pandas using urls from the values, adds a game identifier to each file (the corresponding key), concatenates all dataframe into one and returns it."

# %%
import numpy as npimport pandas as pdimport matplotlib.pyplot as pltDATA_CONFIG = {    "boring": "https://github.com/cyneuro/CI-BioEng-Class/raw/refs/heads/main/emotion_recognition/data/S01G1AllChannels.csv",    "calm": "https://github.com/cyneuro/CI-BioEng-Class/raw/refs/heads/main/emotion_recognition/data/S01G2AllChannels.csv",    "horror": "https://github.com/cyneuro/CI-BioEng-Class/raw/refs/heads/main/emotion_recognition/data/S01G3AllChannels.csv",    "funny": "https://github.com/cyneuro/CI-BioEng-Class/raw/refs/heads/main/emotion_recognition/data/S01G4AllChannels.csv"}

# %%
# 💻 Module 1 — Paste your AI-generated get_data() code here:

# %%
data = get_data(DATA_CONFIG)data.head()

# %% [markdown]
# ### 🧭 Module 2 — Data Analysis> "Assume the columns of my dataframe are recordings from individual electrodes (AF3 to T8), with the identifier saved in the 'game' column. Write a function `run_anova(data)` that takes each electrode in the data separately (AF3 to T8) and runs a simple ANOVA between the games. Print out the composite significance results table."

# %%
# 💻 Module 2 — Paste your AI-generated run_anova() code here:

# %%
anova_result = run_anova(data)

# %% [markdown]
# ### ✍️ Part B Reflection*Double-click this cell to write your response.** **What I observed:** How many electrodes came out statistically significant? Does that match what you'd expect from four emotionally different games?* **Connecting to key concepts:** Connects to **Certification Concept 3** — why analysis is kept separate from data loading and visualization. Explain, in your own words, why `run_anova()` doesn't know or care how `get_data()` fetched its input.---> ## ✅ Colab 1-1 Submission Checkpoint (due end of Week 1)> Submit through Module 2 and its reflection — the Primer activity and data acquisition + statistical analysis.---## 📊 Part C (Build 2 of 2): Visualizing and Documenting Your Results### Topic: Turning Statistics Into a Reproducible Record### 🧭 Module 3 — Visualizing Results> "Now write a function `plot_results()` that takes a dataframe in this format and makes a seaborn histogram showing averages and SEMs. It should also take the `anova_result` table from the previous step and indicate significance with stars and no significance with NS."

# %%
# 💻 Module 3 — Paste your AI-generated plot_results() code here:

# %%
plot_results(data, anova_result)

# %% [markdown]
# ### 🧭 Module 4 — Documenting Research> "Assume the anova table from above is saved in the `anova_result` variable. Write a documentation logging function `document_research` that creates a pandas dataframe with the following columns: current date, number of significant (p < 0.05) electrodes, and returns it."

# %%
# 💻 Module 4 — Paste your AI-generated document_research() code here:

# %%
document_research(anova_result)

# %% [markdown]
# ### 🧭 Embedded Playground**Task 1.** Hypothesize which two game types are likely to produce the most different emotional responses, then re-run the analysis using only those two conditions.**Task 2.** Use AI to add basic preprocessing (re-referencing, filtering) to the workflow between data acquisition and the ANOVA step, and see whether it changes which electrodes come out significant.

# %%
# 🧭 Embedded Playground — run your full pipeline heredata = get_data(DATA_CONFIG)anova_result = run_anova(data)plot_results(data, anova_result)document_research(anova_result)

# %% [markdown]
# ### ✍️ Part C Reflection*Double-click this cell to write your response.** **What I observed:** What did Task 1 and Task 2 change about your results? Did narrowing to two conditions or adding preprocessing shift which electrodes were significant?* **Connecting to key concepts:** Connects to **Certification Concept 5** — why a workflow saves a small log (like your `document_research()` output) alongside results. What would you lose if you skipped this step and only kept the plot?---> ## ✅ Colab 1-2 Submission Checkpoint (due end of Week 2, combined)> Submit the complete notebook (Parts A, B, and C, all reflections, both Embedded Playground tasks). This is the full Colab 1 deliverable and earns the CI hardware/software (including edge computing) microcredential.---## 📑 What Comes NextColab 2 scales this same pipeline from one participant to all 28 — and this time you provision and use a real FABRIC computing session yourself, training a neural network instead of running per-electrode statistics.

# %% [markdown]
# ---## 📖 Reference Guide: Concepts Used in Colab 1**From the master 50:** Concept 3 (why analysis is separated from data loading and visualization), Concept 5 (why workflows log their own settings and results).**From FABRIC's 15:** Concept 1 (Research Testbed), Concept 8 (Project Membership), Concept 16–18 (Compute Environments: Colab, testbed JupyterHub, VSCode).---## ✅ Self-Check: What Did You Learn?| Concept Area | Concept | Where You Demonstrated It ||---|---|---|| Computing | Concept 3 — Separating analysis from loading/visualization | [ Enter Module ID ] || Computing | Concept 5 — Why workflows log their own results | [ Enter Module ID ] || Compute Environments | Concepts 16–18 — Colab vs. testbed JupyterHub vs. VSCode | [ Enter Activity ID ] || Statistics | Per-electrode ANOVA across conditions | [ Enter Module ID ] |
